# %% [markdown]
# # **Some Randon Questions Solution from Previous Years**

# %% [markdown]
# ### Exam Practice.21-22 1(a)

# %%
# %%clingo -V0 0
# a:-b.
# a:-not b,c.
# b:-not c.
# c:- not b,d.
# d:- a,c.
# d:-not a.
# Out:
# a b
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.21-22 1(b)

# %%
# %%clingo -V0 0
# a:- not c.
# b:- a, not d.
# b:- not a, not c.
# c:- not b,a.
# c:- not d.
# d:- not c,a.
# Out:
# c
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.21-22 2(a)

# %%
# %%clingo -V0 0
# k(a;b;c).
#
# % ekhane new ekta var sathe a;b;c dilam x ke safe korar jonno,
# %jekhane bolbe X is unsafe sekhane new var er sathe X dibo
# % stable model theke new var er gula bad jabe
#
# p(a).
# p(b).
# p(c).
# q(c).
# r(X):- p(X), not q(X).
# s(X, Y ) :- r(X), r(Y ).
# t(X) :- s(X, Y ), not t(Y ), not eq(X, Y ).
# t(X) :- s(Y, X), not t(Y ), not eq(Y, X).
# eq(X, X):-k(X).
# Out:
# p(a) p(b) p(c) q(c) r(a) r(b) s(a,a) s(b,a) s(a,b) s(b,b) eq(a,a) eq(b,b) eq(c,c) k(a) k(b) k(c) t(a)
# p(a) p(b) p(c) q(c) r(a) r(b) s(a,a) s(b,a) s(a,b) s(b,b) eq(a,a) eq(b,b) eq(c,c) k(a) k(b) k(c) t(b)
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.21-22 2(b)

# %%
# %%clingo -V0 0
#
# a(a;b;c).
#
# % ekhane new ekta var sathe a;b;c dilam x ke safe korar jonno,
# %jekhane bolbe X is unsafe sekhane new var er sathe X dibo
# % stable model theke new var er gula bad jabe
# p(a,b,c).
# p(X, X, X):-a(X).
# q(X, Y) :- p(X,Y,Z), not p(Y,Y,Y).
# s(X, X) :- not q(X,X), a(X).
# Out:
# a(a) a(b) a(c) p(a,b,c) p(a,a,a) p(b,b,b) p(c,c,c) s(a,a) s(b,b) s(c,c)
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.20-21 (1)

# %%
# %%clingo -V0 0
# a.
# a:-e.
# c:-a.
# d:-a,c.
# e:-e.
# f:-e.
# f:-d,g.
# g:-a,e,f.
# g:-a,f.
# Out:
# a c d
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.20-21 Logic Program with Variables(4)

# %%
# %%clingo -V0 0
# a(0,2).
# a(1,1).
# a(1,3).
# a(2,4).
# b(X):- a(X,Y).
# c(X,Y):- a(X,Y), not d(X,Y).
# d(X,Y):- a(X,Y), not c(X,Y), not b(Y).
# Out:
# a(0,2) a(1,1) a(1,3) a(2,4) b(0) b(1) b(2) c(0,2) c(1,1) d(1,3) d(2,4)
# a(0,2) a(1,1) a(1,3) a(2,4) b(0) b(1) b(2) c(0,2) c(1,1) d(1,3) c(2,4)
# a(0,2) a(1,1) a(1,3) a(2,4) b(0) b(1) b(2) c(0,2) c(1,1) c(1,3) d(2,4)
# a(0,2) a(1,1) a(1,3) a(2,4) b(0) b(1) b(2) c(0,2) c(1,1) c(1,3) c(2,4)
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.19-20 (4)

# %%
# %%clingo -V0 0
# a(0, 1).
# a(0, 2).
# a(1, 2).
# b(X) :- a(X, Y ), not r(X, Y ).
# b(Y ) :- r(X, Y ).
# r(X, Y ) :- a(X, Y ), not b(X).
# r(X, Y ) :- a(X, Y ), a(Y, Z), b(Z).
# % ans gula 2 line a set kore likhte hobe {}
# Out:
# a(0,1) a(0,2) a(1,2) b(0) b(1)
# a(0,1) a(0,2) a(1,2) r(0,1) r(0,2) b(1) b(2)
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.19-20 (3)
# Determine the stable models of the following extended logic program P :
# 1 {a, b}.      {a, b, c} 2 ← 2 {a, b, d}.     d ← 1 {a, c} 1.Q a comma thake or use kore solve

# %%
# %%clingo -V0 0
# 1 { a ; b }.
# { a; b;c} 2 :- 2 {a; b;d}.
# d:-1{a;c}1 .
# % Ans: {a,b,d}, {a,d}, {b}
# Out:
# b
# d a b
# d a
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.17-18 (1)

# %%
# %%clingo -V0 0
# a:- c,g.
# a:- d,f.
# b:-e.
# c:-a,f.
# d:- b,g.
# d:-c,e.
# e.
# g:-a,d.
# g:-b,e.
# Out:
# g d e b
# SATISFIABLE
# -:2:7-8: info: atom does not occur in any rule head:
#   f
#
# -:4:6-7: info: atom does not occur in any rule head:
#   f

# %% [markdown]
# ### Exam Practice.17-18 (2)

# %%
# %%clingo -V0 0
# a:-b.
# a:-not c.
# b:-a,c.
# b:- not c, not d.
# c:-b, not d.
# c:- not a.
# d:- a, not b.
# d:- c, not a.
# Out:
# c d
# a d
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.17-18 (3)

# %%
# %%clingo -V0 0
# %this type of question answer 2 set a likhte hobe
# p(a,b).
# p(a,c).
# p(b,c).
# q(X):-p(X,Y), not r(X,Y).
# q(Y):- r(X,Y).
# r(X,Y):- p(X,Y), not q(X).
# r(X,Y):- p(X,Y), p(Y,Z), q(Z).
# Out:
# p(a,b) p(a,c) p(b,c) q(a) q(b)
# p(a,b) p(a,c) p(b,c) r(a,b) r(a,c) q(b) q(c)
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.17-18 (5)

# %%
# %%clingo -V0 0
# a(a;b;c).
# above(a,b).
# above(a,c).
# above(b,c).
# on(X):- above(X,Y).
# switch(X):- not on(X), a(X).
# next(X,Y):- switch(X),a(Y).
# next(X,Y):-above(X,Y), not switch(Y).
# Out:
# above(a,b) above(a,c) above(b,c) on(a) on(b) a(a) a(b) a(c) switch(c) next(a,b) next(c,a) next(c,b) next(c,c)
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.17-18 (7)

# %%
# %%clingo -V0 0
# a:- b, not c.
# a:- not f.
# b:- c, not e.
# b:- d,e.
# c:- a,b.
# c:-e.
# d:- a, not c.
# e:- c, not b.
# Out:
# a d
# SATISFIABLE
# -:2:9-10: info: atom does not occur in any rule head:
#   f

# %% [markdown]
# #### **Practice**

# %%
# %%clingo -V0 0
# linked(0,1).
# linked(1,2).
# linked(2,3).
# reachable(1).
# reachable(X):- reachable(Y), linked(Y,X).
# middle(X):- linked(X,Y), linked(Z,X).
# Out:
# linked(0,1) linked(1,2) linked(2,3) reachable(1) reachable(2) reachable(3) middle(1) middle(2)
# SATISFIABLE

# %%
# %%clingo -V0 0
# a(alice;bob;charlie;daniel;ethan).
# myfriend(alice).
# friends(alice, bob).
# friends(bob, charlie).
# friends(bob, daniel).
# friends(daniel, ethan).
# myfriend(X):- myfriend(Y), friends(Y,X), not myenemy(X).
# myenemy(X):- not myfriend(X), a(X).
# Out:
# friends(alice,bob) friends(bob,charlie) friends(bob,daniel) friends(daniel,ethan) myfriend(alice) a(alice) a(bob) a(charlie) a(daniel) a(ethan) myfriend(bob) myfriend(charlie) myfriend(daniel) myfriend(ethan)
# friends(alice,bob) friends(bob,charlie) friends(bob,daniel) friends(daniel,ethan) myfriend(alice) a(alice) a(bob) a(charlie) a(daniel) a(ethan) myfriend(bob) myfriend(charlie) myfriend(daniel) myenemy(ethan)
# friends(alice,bob) friends(bob,charlie) friends(bob,daniel) friends(daniel,ethan) myfriend(alice) a(alice) a(bob) a(charlie) a(daniel) a(ethan) myfriend(bob) myenemy(charlie) myfriend(daniel) myfriend(ethan)
# friends(alice,bob) friends(bob,charlie) friends(bob,daniel) friends(daniel,ethan) myfriend(alice) a(alice) a(bob) a(charlie) a(daniel) a(ethan) myfriend(bob) myenemy(charlie) myfriend(daniel) myenemy(ethan)
# ...

# %% [markdown]
# ### Exam Practice.17-18 (8)

# %%
# %%clingo -V0 0
# a:- b,d.
# a:- e, not c.
# b:- not d.
# c:- d,e.
# d:- b.
# d:- not a.
# e:- a,c.
# e:-d.
# Out:
# d e c
# SATISFIABLE

# %% [markdown]
# ### Exam Practice.17-18 (9)

# %%
# %%clingo -V0 0
# a:-c,not f.
# a:-e, not d.
# b.
# c:- a, not e.
# c:- d,g.
# d:- e,f.
# e:- b, not g.
# f:- d, not a.
# f:- not b, not c.
# Out:
# a e b
# SATISFIABLE
# -:5:7-8: info: atom does not occur in any rule head:
#   g
#
# -:7:12-13: info: atom does not occur in any rule head:
#   g
